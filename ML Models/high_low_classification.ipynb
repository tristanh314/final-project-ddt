# %% [markdown]
# ## Setup

# %%
# Import Dependencies.
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import requests
import json

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler

from tensorflow.keras.models import load_model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

from joblib import dump, load

# %%
# Fetch the data from the API.
listings_json = requests.get("http://127.0.0.1:5000/housingDataAPI/v1.0/listings").json()

# Examine the data.
print(json.dumps(listings_json[0], indent=4, sort_keys=True))
# Out:
# {
#     "address": "17452 NE GLISAN ST #7, Portland OR 97230",
#     "bathrooms": 2.0,
#     "bedrooms": 2,
#     "built": 1988,
#     "city": "Portland",
#     "county": "Multnomah",
#     "elementary_school": "Hartley",
#     "high_school": "Reynolds",
#     "home_type": "Manufactured - Double Wide Manufact",
#     "lot_size": null,
#     "middle_school": "Reynolds",
#     "neighborhood": "unknown",
#     "price": 72000,
#     "square_feet": 1152,
#     "zipcode": 97230
# }

# %%
# Create a dataframe to use for our model.
data_df = pd.DataFrame(listings_json)

print(len(data_df))
data_df.head()
# Out:
# 1822
#                                       address  bathrooms  bedrooms  built  \
# 0    17452 NE GLISAN ST #7, Portland OR 97230        2.0         2   1988
# 1  16000 SE POWELL BLVD 75, Portland OR 97236        2.0         3   1990
# 2     12846 SE RAMONA ST 6, Portland OR 97236        2.0         3   1997
# 3     7720 S Macadam AVE 7, Portland OR 97219        3.0         3   1988
# 4   19609 NE Marine DR E-4, Portland OR 97230        1.0         1   1960
#
#        city     county elementary_school    high_school  \
# 0  Portland  Multnomah           Hartley       Reynolds
# 1  Portland  Multnomah      Powell Butte     Centennial
# 2  Portland  Multnomah       Gilbert Hts  David Douglas
# 3  Portland  Multnomah             Other          Other
# 4  Portland  Multnomah       Salish Pond       Reynolds
#
#                              home_type  lot_size middle_school neighborhood  \
# 0  Manufactured - Double Wide Manufact       NaN      Reynolds      unknown
# 1  Manufactured - Double Wide Manufact       NaN    Centennial      unknown
# 2  Manufactured - Double Wide Manufact       NaN     Alice Ott      unknown
# 3         Floating Home - Contemporary       NaN         Other      unknown
# 4                Floating Home - Cabin       NaN      Reynolds      unknown
#
#     price  square_feet  zipcode
# 0   72000         1152    97230
# 1   79950         1404    97236
# 2   93900         1297    97236
# 3  125000         2432    97219
# 4  129500          735    97230

# %% [markdown]
# ## Data Preprocessing

# %%
# Make a copy of the original data frame to modify.
model_df = data_df

# Insert a lot value of 0 for condos and floating homes.
for index, row in model_df.iterrows():
    if ("Condo" in row["home_type"]) | ("Floating" in row["home_type"]):
        model_df.loc[index, "lot_size"] = 0
    else:
        pass

# Include only those columns that will be used in the deep learning model.
model_df = model_df.loc[:, ["bathrooms", "bedrooms", "built", "lot_size", "square_feet", "home_type", "price"]]
# Chose not to include high_school due to lousy random forest fitting.
# Drop rows with NaN entries.
model_df.dropna(inplace=True)

# Bin prices into ten equal length ranges.
model_df["price_range"] = pd.qcut(model_df["price"], 5)
# Drop the original price data.
model_df.drop("price", axis=1, inplace=True)

# Check the model data.
print(len(model_df))
model_df.head()
# Out:
# 1725
#    bathrooms  bedrooms  built  lot_size  square_feet  \
# 3        3.0         3   1988       0.0         2432
# 4        1.0         1   1960       0.0          735
# 5        1.0         1   1974       0.0          720
# 6        1.0         1   1927       0.0          382
# 7        1.0         1   2004       0.0          513
#
#                       home_type             price_range
# 3  Floating Home - Contemporary  (124999.999, 349000.0]
# 4         Floating Home - Cabin  (124999.999, 349000.0]
# 5           Condo - Traditional  (124999.999, 349000.0]
# 6           Condo - Common Wall  (124999.999, 349000.0]
# 7                 Condo - Other  (124999.999, 349000.0]

# %%
# Simplify home types in model_df.
for i in model_df.index:
    if "Floating" in model_df.at[i, "home_type"]:
        model_df.at[i, "home_type"] = "Floating"
    if "Condo" in model_df.at[i, "home_type"]:
        model_df.at[i, "home_type"] = "Condo"
    if "Single Family" in model_df.at[i, "home_type"]:
        model_df.at[i, "home_type"] = "Single Family"
    if "Manufactured" in model_df.at[i, "home_type"]:
        model_df.at[i, "home_type"] = "Manufactured"
    
model_df.head()
# Out:
#    bathrooms  bedrooms  built  lot_size  square_feet home_type  \
# 3        3.0         3   1988       0.0         2432  Floating
# 4        1.0         1   1960       0.0          735  Floating
# 5        1.0         1   1974       0.0          720     Condo
# 6        1.0         1   1927       0.0          382     Condo
# 7        1.0         1   2004       0.0          513     Condo
#
#               price_range
# 3  (124999.999, 349000.0]
# 4  (124999.999, 349000.0]
# 5  (124999.999, 349000.0]
# 6  (124999.999, 349000.0]
# 7  (124999.999, 349000.0]

# %%
# Get dummies for the values in home_type to use in the model.
model_df = pd.get_dummies(model_df, columns=["home_type"])
model_df.head()
# Out:
#    bathrooms  bedrooms  built  lot_size  square_feet             price_range  \
# 3        3.0         3   1988       0.0         2432  (124999.999, 349000.0]
# 4        1.0         1   1960       0.0          735  (124999.999, 349000.0]
# 5        1.0         1   1974       0.0          720  (124999.999, 349000.0]
# 6        1.0         1   1927       0.0          382  (124999.999, 349000.0]
# 7        1.0         1   2004       0.0          513  (124999.999, 349000.0]
#
#    home_type_Condo  home_type_Floating  home_type_Manufactured  \
# 3                0                   1                       0
# 4                0                   1                       0
# 5                1                   0                       0
# 6                1                   0                       0
# 7                1                   0                       0
#
#    home_type_Single Family
# 3                        0
# 4                        0
# 5                        0
# 6                        0
# 7                        0

# %%
# Assign X (input) and y (target).

X = model_df.drop("price_range", axis=1)
y = model_df["price_range"]

# %%
# Split the data into training and testing

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Create a MinMaxScaler model and fit it to the training data

X_scaler = MinMaxScaler().fit(X_train)

# Save the scalar.
dump(X_scaler, 'minmax_scaler.bin', compress=True)
# Out:
# ['minmax_scaler.bin']

# %%
# Transform the training and testing data using the X_scaler and y_scaler models.

X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Label encode the target data.
label_encoder = LabelEncoder()
label_encoder.fit(y_train)
encoded_y_train = label_encoder.transform(y_train)
encoded_y_test = label_encoder.transform(y_test)

# Save the label encoder
dump(label_encoder, 'label_encoder.bin', compress=True)
# Out:
# ['label_encoder.bin']

# %%
# Convert encoded labels to one-hot encoding.
y_train_categorical = to_categorical(encoded_y_train)
y_test_categorical = to_categorical(encoded_y_test)

# %% [markdown]
# ## Run Random Forest Classifier

# %%
# Create a random forest classifier, fit to the training data, and score on the testing data.
rf = RandomForestClassifier(n_estimators=1000)
rf = rf.fit(X_train_scaled, y_train_categorical)
print(rf.score(X_test_scaled, y_test_categorical))

# Find the importances of each feature.
feature_names = X.columns
importances = rf.feature_importances_
print(sorted(zip(rf.feature_importances_, feature_names), reverse=True))
# Out:
# 0.5300925925925926
# [(0.44928706573335603, 'square_feet'), (0.23200249195892506, 'built'), (0.11439141434438334, 'lot_size'), (0.09574016278543077, 'bathrooms'), (0.08081807817507289, 'bedrooms'), (0.011965381304771861, 'home_type_Single Family'), (0.011559706140583869, 'home_type_Condo'), (0.0039034236117335068, 'home_type_Floating'), (0.0003322759457426507, 'home_type_Manufactured')]

# %% [markdown]
# ## Create a Deep Learning Model

# %%
# Create a deep learning Sequential model.
deep_model = Sequential()
deep_model.add(Dense(units=100, activation='relu', input_dim=9))
deep_model.add(Dense(units=100, activation='relu'))
deep_model.add(Dense(units=5, activation='softmax'))

# %%
# Compile and fit the model.
deep_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

deep_model.fit(
    X_train_scaled,
    y_train_categorical,
    epochs=100,
    shuffle=True,
    verbose=2
)
# Out:
# Train on 1293 samples
# Epoch 1/100
# 1293/1293 - 1s - loss: 1.5447 - accuracy: 0.2978
# Epoch 2/100
# 1293/1293 - 0s - loss: 1.4399 - accuracy: 0.3790
# Epoch 3/100
# 1293/1293 - 0s - loss: 1.3426 - accuracy: 0.4223
# Epoch 4/100
# 1293/1293 - 0s - loss: 1.2589 - accuracy: 0.4532
# Epoch 5/100
# 1293/1293 - 0s - loss: 1.2001 - accuracy: 0.4834
# Epoch 6/100
# 1293/1293 - 0s - loss: 1.1654 - accuracy: 0.5073
# Epoch 7/100
# 1293/1293 - 0s - loss: 1.1483 - accuracy: 0.5205
# Epoch 8/100
# 1293/1293 - 0s - loss: 1.1234 - accuracy: 0.5228
# Epoch 9/100
# 1293/1293 - 0s - loss: 1.1063 - accuracy: 0.5290
# Epoch 10/100
# 1293/1293 - 0s - loss: 1.0943 - accuracy: 0.5305
# Epoch 11/100
# 1293/1293 - 0s - loss: 1.0875 - accuracy: 0.5391
# Epoch 12/100
# 1293/1293 - 0s - loss: 1.0737 - accuracy: 0.5553
# Epoch 13/100
# 1293/1293 - 0s - loss: 1.0601 - accuracy: 0.5592
# Epoch 14/100
# 1293/1293 - 0s - loss: 1.0541 - accuracy: 0.5615
# Epoch 15/100
# 1293/1293 - 0s - loss: 1.0348 - accuracy: 0.5731
# Epoch 16/100
# 1293/1293 - 0s - loss: 1.0326 - accuracy: 0.5770
# Epoch 17/100
# 1293/1293 - 0s - loss: 1.0246 - accuracy: 0.5638
# Epoch 18/100
# 1293/1293 - 0s - loss: 1.0172 - accuracy: 0.5847
# Epoch 19/100
# 1293/1293 - 0s - loss: 1.0082 - accuracy: 0.5762
# Epoch 20/100
# 1293/1293 - 0s - loss: 1.0104 - accuracy: 0.5677
# Epoch 21/100
# 1293/1293 - 0s - loss: 1.0034 - accuracy: 0.5785
# Epoch 22/100
# 1293/1293 - 0s - loss: 1.0069 - accuracy: 0.5770
# Epoch 23/100
# 1293/1293 - 0s - loss: 0.9943 - accuracy: 0.5777
# Epoch 24/100
# 1293/1293 - 0s - loss: 0.9881 - accuracy: 0.5816
# Epoch 25/100
# 1293/1293 - 0s - loss: 0.9917 - accuracy: 0.5800
# Epoch 26/100
# 1293/1293 - 0s - loss: 0.9902 - accuracy: 0.5839
# Epoch 27/100
# 1293/1293 - 0s - loss: 0.9879 - accuracy: 0.5800
# Epoch 28/100
# 1293/1293 - 0s - loss: 0.9815 - accuracy: 0.5824
# Epoch 29/100
# 1293/1293 - 0s - loss: 0.9813 - accuracy: 0.5870
# Epoch 30/100
# 1293/1293 - 0s - loss: 0.9822 - accuracy: 0.5739
# Epoch 31/100
# 1293/1293 - 0s - loss: 0.9756 - accuracy: 0.5870
# Epoch 32/100
# 1293/1293 - 0s - loss: 0.9771 - accuracy: 0.5847
# Epoch 33/100
# 1293/1293 - 0s - loss: 0.9702 - accuracy: 0.5862
# Epoch 34/100
# 1293/1293 - 0s - loss: 0.9687 - accuracy: 0.5839
# Epoch 35/100
# 1293/1293 - 0s - loss: 0.9829 - accuracy: 0.5754
# Epoch 36/100
# 1293/1293 - 0s - loss: 0.9670 - accuracy: 0.5824
# Epoch 37/100
# 1293/1293 - 0s - loss: 0.9676 - accuracy: 0.5855
# Epoch 38/100
# 1293/1293 - 0s - loss: 0.9642 - accuracy: 0.5940
# Epoch 39/100
# 1293/1293 - 0s - loss: 0.9679 - accuracy: 0.5855
# Epoch 40/100
# 1293/1293 - 0s - loss: 0.9657 - accuracy: 0.5777
# Epoch 41/100
# 1293/1293 - 0s - loss: 0.9768 - accuracy: 0.5824
# Epoch 42/100
# 1293/1293 - 0s - loss: 0.9577 - accuracy: 0.5777
# Epoch 43/100
# 1293/1293 - 0s - loss: 0.9564 - accuracy: 0.5955
# Epoch 44/100
# 1293/1293 - 0s - loss: 0.9650 - accuracy: 0.5855
# Epoch 45/100
# 1293/1293 - 0s - loss: 0.9589 - accuracy: 0.5886
# Epoch 46/100
# 1293/1293 - 0s - loss: 0.9556 - accuracy: 0.5932
# Epoch 47/100
# 1293/1293 - 0s - loss: 0.9520 - accuracy: 0.5893
# Epoch 48/100
# 1293/1293 - 0s - loss: 0.9583 - accuracy: 0.5855
# Epoch 49/100
# 1293/1293 - 0s - loss: 0.9538 - accuracy: 0.5971
# Epoch 50/100
# 1293/1293 - 0s - loss: 0.9512 - accuracy: 0.5909
# Epoch 51/100
# 1293/1293 - 0s - loss: 0.9468 - accuracy: 0.5924
# Epoch 52/100
# 1293/1293 - 0s - loss: 0.9489 - accuracy: 0.5893
# Epoch 53/100
# 1293/1293 - 0s - loss: 0.9463 - accuracy: 0.5971
# Epoch 54/100
# 1293/1293 - 0s - loss: 0.9480 - accuracy: 0.5901
# Epoch 55/100
# 1293/1293 - 0s - loss: 0.9435 - accuracy: 0.5963
# Epoch 56/100
# 1293/1293 - 0s - loss: 0.9436 - accuracy: 0.6025
# Epoch 57/100
# 1293/1293 - 0s - loss: 0.9514 - accuracy: 0.6002
# Epoch 58/100
# 1293/1293 - 0s - loss: 0.9444 - accuracy: 0.5963
# Epoch 59/100
# 1293/1293 - 0s - loss: 0.9545 - accuracy: 0.5878
# Epoch 60/100
# 1293/1293 - 0s - loss: 0.9408 - accuracy: 0.5955
# Epoch 61/100
# 1293/1293 - 0s - loss: 0.9426 - accuracy: 0.5971
# Epoch 62/100
# 1293/1293 - 0s - loss: 0.9465 - accuracy: 0.5986
# Epoch 63/100
# 1293/1293 - 0s - loss: 0.9420 - accuracy: 0.5901
# Epoch 64/100
# 1293/1293 - 0s - loss: 0.9431 - accuracy: 0.6025
# Epoch 65/100
# 1293/1293 - 0s - loss: 0.9393 - accuracy: 0.5986
# Epoch 66/100
# 1293/1293 - 0s - loss: 0.9416 - accuracy: 0.5971
# Epoch 67/100
# 1293/1293 - 0s - loss: 0.9359 - accuracy: 0.5947
# Epoch 68/100
# 1293/1293 - 0s - loss: 0.9333 - accuracy: 0.6002
# Epoch 69/100
# 1293/1293 - 0s - loss: 0.9364 - accuracy: 0.6040
# Epoch 70/100
# 1293/1293 - 0s - loss: 0.9380 - accuracy: 0.5916
# Epoch 71/100
# 1293/1293 - 0s - loss: 0.9286 - accuracy: 0.6048
# Epoch 72/100
# 1293/1293 - 0s - loss: 0.9325 - accuracy: 0.5963
# Epoch 73/100
# 1293/1293 - 0s - loss: 0.9404 - accuracy: 0.5994
# Epoch 74/100
# 1293/1293 - 0s - loss: 0.9327 - accuracy: 0.5947
# Epoch 75/100
# 1293/1293 - 0s - loss: 0.9330 - accuracy: 0.5994
# Epoch 76/100
# 1293/1293 - 0s - loss: 0.9350 - accuracy: 0.6025
# Epoch 77/100
# 1293/1293 - 0s - loss: 0.9256 - accuracy: 0.6063
# Epoch 78/100
# 1293/1293 - 0s - loss: 0.9361 - accuracy: 0.6025
# Epoch 79/100
# 1293/1293 - 0s - loss: 0.9247 - accuracy: 0.6017
# Epoch 80/100
# 1293/1293 - 0s - loss: 0.9271 - accuracy: 0.6017
# Epoch 81/100
# 1293/1293 - 0s - loss: 0.9273 - accuracy: 0.6056
# Epoch 82/100
# 1293/1293 - 0s - loss: 0.9268 - accuracy: 0.6002
# Epoch 83/100
# 1293/1293 - 0s - loss: 0.9264 - accuracy: 0.5978
# Epoch 84/100
# 1293/1293 - 0s - loss: 0.9320 - accuracy: 0.5901
# Epoch 85/100
# 1293/1293 - 0s - loss: 0.9435 - accuracy: 0.5855
# Epoch 86/100
# 1293/1293 - 0s - loss: 0.9290 - accuracy: 0.6071
# Epoch 87/100
# 1293/1293 - 0s - loss: 0.9259 - accuracy: 0.5963
# Epoch 88/100
# 1293/1293 - 0s - loss: 0.9244 - accuracy: 0.6110
# Epoch 89/100
# 1293/1293 - 0s - loss: 0.9175 - accuracy: 0.5955
# Epoch 90/100
# 1293/1293 - 0s - loss: 0.9213 - accuracy: 0.6048
# Epoch 91/100
# 1293/1293 - 0s - loss: 0.9209 - accuracy: 0.5971
# Epoch 92/100
# 1293/1293 - 0s - loss: 0.9198 - accuracy: 0.6048
# Epoch 93/100
# 1293/1293 - 0s - loss: 0.9163 - accuracy: 0.6087
# Epoch 94/100
# 1293/1293 - 0s - loss: 0.9203 - accuracy: 0.6079
# Epoch 95/100
# 1293/1293 - 0s - loss: 0.9250 - accuracy: 0.6025
# Epoch 96/100
# 1293/1293 - 0s - loss: 0.9182 - accuracy: 0.6079
# Epoch 97/100
# 1293/1293 - 0s - loss: 0.9204 - accuracy: 0.6002
# Epoch 98/100
# 1293/1293 - 0s - loss: 0.9188 - accuracy: 0.6094
# Epoch 99/100
# 1293/1293 - 0s - loss: 0.9157 - accuracy: 0.6102
# Epoch 100/100
# 1293/1293 - 0s - loss: 0.9175 - accuracy: 0.6118

# %% [markdown]
# ## Quantify our Trained Model

# %%
model_loss, model_accuracy = deep_model.evaluate(X_test_scaled, y_test_categorical, verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")

# %% [markdown]
# ## Make Predictions

# %%
# Use the first 10 test data values to make a prediction and compare it to the actual labels.
encoded_predictions = deep_model.predict_classes(X_test_scaled[:10])
prediction_labels = label_encoder.inverse_transform(encoded_predictions)

print(f"Predicted classes: {prediction_labels}")
print(f"Actual Labels: {list(y_test[:10])}")

# %% [markdown]
# ## Save the trained model

# %%
# Save the model
deep_model.save("housing_model_trained.h5")

# %% [markdown]
# ## Test the saved model, scaler, and label encoder

# %%
# Load the model, scaler and label encoder.
model = load_model("housing_model_trained.h5")
scaler = load("minmax_scaler.bin")
label_encoder = load("label_encoder.bin")

# %%
# Input data as bathrooms, bedrooms, built, lot_size, square_feet
input_data = np.array([[3, 4, 1920, 0.5, 1075]])

# %%
encoded_predictions = model.predict_classes(input_data)
prediction_labels = label_encoder.inverse_transform(encoded_predictions)

print(f"{prediction_labels[0].right}")
